# %%
import numpy as np
import pandas as pd
import sys
from pathlib import Path as P
r = P.cwd() if (P.cwd() / "src").exists() else P.cwd().parent
sys.path[:0] = [str(r / "src"), str(r)]
from simulation_scripts.execute_simulations import *
from retrieval_methods.inline_retrieval import *

# %% [markdown]
# # Load Simulation Parameters

# %%
param_card_dict = np.load("../data/param_cards/Param_Card_PBI_Poly.npy", allow_pickle=True)

pd.DataFrame(param_card_dict.item().items(), columns=["Parameter", "Value"])
# Out:
#                              Parameter  \
# 0                     Type of spectrum
# 1                      Source geometry
# 2                         Energy (keV)
# 3                 Focal spot size (μm)
# 4                      Sim. pixel (μm)
# 5                            FOV (pix)
# 6                Num. events per pixel
# 7                       Binning factor
# 8                       FWHM PSF (pix)
# 9                             Geometry
# 10         Whole sample thickness (mm)
# 11                     Sample material
# 12      Sample material density (g/cc)
# 13                 Background material
# 14  Background material density (g/cc)
# 15                 Fibre diameter (mm)
# 16        Source-Detector distance (m)
# 17          Source-Sample distance (m)
#
#                                                 Value
# 0                                                Poly
# 1                                            Parallel
# 2   /Users/manuelfernandosanchezalarcon/Desktop/CA...
# 3                                                   0
# 4                                                   1
# 5                                           (300,300)
# 6                                                5000
# 7                                                   2
# 8                                                   6
# 9                                               fibre
# 10                                                 44
# 11                                            C6H11NO
# 12                                               1.14
# 13                                                 N2
# 14                                             0.0012
# 15                                               0.03
# 16                                                1.0
# 17                                               0.55

# %% [markdown]
# # Calculate Reference Image

# %%
show_reference_Inline(param_card_dict.item())
# Out:
# Obtaining reference and sample images for Energy = 21.0 keV

# %% [markdown]
# # Save Reference (Flat-Field) and Sample Images

# %%
run_Inline_sim(param_card_dict.item(), save_path="../results/PBI_Poly/")
# Out:
# Running simulation...
# Obtaining reference and sample images for Energy = 1.25 keV
# Obtaining reference and sample images for Energy = 1.75 keV
# Obtaining reference and sample images for Energy = 2.25 keV
# Obtaining reference and sample images for Energy = 2.75 keV
# Obtaining reference and sample images for Energy = 3.25 keV
# Obtaining reference and sample images for Energy = 3.75 keV
# Obtaining reference and sample images for Energy = 4.25 keV
# Obtaining reference and sample images for Energy = 4.75 keV
# Obtaining reference and sample images for Energy = 5.25 keV
# Obtaining reference and sample images for Energy = 5.75 keV
# Obtaining reference and sample images for Energy = 6.25 keV
# Obtaining reference and sample images for Energy = 6.75 keV
# Obtaining reference and sample images for Energy = 7.25 keV
# Obtaining reference and sample images for Energy = 7.75 keV
# Obtaining reference and sample images for Energy = 8.25 keV
# Obtaining reference and sample images for Energy = 8.75 keV
# Obtaining reference and sample images for Energy = 9.25 keV
# Obtaining reference and sample images for Energy = 9.75 keV
# Obtaining reference and sample images for Energy = 10.25 keV
# Obtaining reference and sample images for Energy = 10.75 keV
# Obtaining reference and sample images for Energy = 11.25 keV
# Obtaining reference and sample images for Energy = 11.75 keV
# Obtaining reference and sample images for Energy = 12.25 keV
# Obtaining reference and sample images for Energy = 12.75 keV
# Obtaining reference and sample images for Energy = 13.25 keV
# Obtaining reference and sample images for Energy = 13.75 keV
# Obtaining reference and sample images for Energy = 14.25 keV
# Obtaining reference and sample images for Energy = 14.75 keV
# Obtaining reference and sample images for Energy = 15.25 keV
# Obtaining reference and sample images for Energy = 15.75 keV
# Obtaining reference and sample images for Energy = 16.25 keV
# Obtaining reference and sample images for Energy = 16.75 keV
# Obtaining reference and sample images for Energy = 17.25 keV
# Obtaining reference and sample images for Energy = 17.75 keV
# Obtaining reference and sample images for Energy = 18.25 keV
# Obtaining reference and sample images for Energy = 18.75 keV
# Obtaining reference and sample images for Energy = 19.25 keV
# Obtaining reference and sample images for Energy = 19.75 keV
# Obtaining reference and sample images for Energy = 20.25 keV
# Obtaining reference and sample images for Energy = 20.75 keV
# Obtaining reference and sample images for Energy = 21.25 keV
# Obtaining reference and sample images for Energy = 21.75 keV
# Obtaining reference and sample images for Energy = 22.25 keV
# Obtaining reference and sample images for Energy = 22.75 keV
# Obtaining reference and sample images for Energy = 23.25 keV
# Obtaining reference and sample images for Energy = 23.75 keV
# Obtaining reference and sample images for Energy = 24.25 keV
# Obtaining reference and sample images for Energy = 24.75 keV
# Obtaining reference and sample images for Energy = 25.25 keV
# Obtaining reference and sample images for Energy = 25.75 keV
# Obtaining reference and sample images for Energy = 26.25 keV
# Obtaining reference and sample images for Energy = 26.75 keV
# Obtaining reference and sample images for Energy = 27.25 keV
# Obtaining reference and sample images for Energy = 27.75 keV
# Simulation finished.

# %% [markdown]
# # Retrieve and Plot Transmission Image

# %%
Iref = np.load("../results/PBI_Poly/I_ref_poly.npy")
Isamp = np.load("../results/PBI_Poly/I_samp_poly.npy")
params = None
get_retrieved_images(Iref, Isamp, params)
